# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding How The Data Is Distributed**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will work with a cleaned dataset to perform Exploratory Data Analysis (EDA). You will examine the structure of the data, visualize key variables, and analyze trends related to developer experience, tools, job satisfaction, and other important aspects.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# - Understand the structure of the dataset.
#
# - Perform summary statistics and data visualization.
#
# - Identify trends in developer experience, tools, job satisfaction, and other key variables.

# %% [markdown]
# ### Install the required libraries

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install SciPy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 179.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 180.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 115.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 79.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 48.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 92.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 125.6 MB/s eta 0:00:0000:01
# ...

# %% [markdown]
# ### Step 1: Import Libraries and Load Data

# %% [markdown]
# - Import the `pandas`, `matplotlib.pyplot`, and `seaborn` libraries.

# %% [markdown]
# - You will begin with loading the dataset. You can use the pyfetch method if working on JupyterLite. Otherwise, you can use pandas' read_csv() function directly on their local machines or cloud environments.

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Stack Overflow survey dataset
data_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv'
df = pd.read_csv(data_url)

from scipy import stats

# (Optional) display settings
pd.set_option('display.max_columns', None)
sns.set(style="whitegrid")


# Display the first few rows of the dataset
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ### Step 2: Examine the Structure of the Data

# %% [markdown]
# - Display the column names, data types, and summary information to understand the data structure.
#
# - Objective: Gain insights into the dataset's shape and available variables.

# %%
df.shape
# Out:
# (65437, 114)

# %%
df.dtypes
# Out:
# ResponseId               int64
# MainBranch              object
# Age                     object
# Employment              object
# RemoteWork              object
#                         ...
# JobSatPoints_11        float64
# SurveyLength            object
# SurveyEase              object
# ConvertedCompYearly    float64
# JobSat                 float64
# Length: 114, dtype: object

# %% [markdown]
# ### Step 3: Handle Missing Data

# %% [markdown]
# - Identify missing values in the dataset.
#
# - Impute or remove missing values as necessary to ensure data completeness.

# %%
df.isnull().sum()
# Out:
# ResponseId                 0
# MainBranch                 0
# Age                        0
# Employment                 0
# RemoteWork             10631
#                        ...
# JobSatPoints_11        35992
# SurveyLength            9255
# SurveyEase              9199
# ConvertedCompYearly    42002
# JobSat                 36311
# Length: 114, dtype: int64

# %%
#find the number of missing values in the specific columns needed
df[['Employment','JobSat','YearsCodePro','Country','LanguageHaveWorkedWith','LanguageWantToWorkWith','RemoteWork']].isnull().sum()
# Out:
# Employment                    0
# JobSat                    36311
# YearsCodePro              13827
# Country                    6507
# LanguageHaveWorkedWith     5692
# LanguageWantToWorkWith     9685
# RemoteWork                10631
# dtype: int64

# %%
print("\nMissing values before cleaning:")
print(df.isnull().sum())

#fill the empty numeric columns with the mean value

numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
for col in numeric_cols:
    df[col].fillna(df[col].mean(), inplace=True)                                                                                                             

# Fill categorical columns with mode
categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)

print("\nMissing values after cleaning:")
print(df.isnull().sum())

# Confirm that rows still exist
print(f"\nData shape after cleaning: {df.shape}")
# Out:
# Missing values before cleaning:
# ResponseId                 0
# MainBranch                 0
# Age                        0
# Employment                 0
# RemoteWork             10631
#                        ...
# JobSatPoints_11        35992
# SurveyLength            9255
# SurveyEase              9199
# ConvertedCompYearly    42002
# JobSat                 36311
# Length: 114, dtype: int64
# /tmp/ipykernel_301/1569399919.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %% [markdown]
# ### Step 4: Analyze Key Columns

# %% [markdown]
# - Examine key columns such as `Employment`, `JobSat` (Job Satisfaction), and `YearsCodePro` (Professional Coding Experience).
#
# - **Instruction**: Calculate the value counts for each column to understand the distribution of responses.

# %%
#ensure all columns required are numeric

df['YearsCodePro'] = pd.to_numeric(df['YearsCodePro'], errors='coerce')
df['Employment'] = pd.to_numeric(df['Employment'], errors='coerce')
df['JobSat'] = pd.to_numeric(df['JobSat'], errors='coerce')
                                 
#print the value counts
print(df['Employment'].value_counts())
print(df['JobSat'].value_counts())
print(df['YearsCodePro'].value_counts())
# Out:
# Series([], Name: count, dtype: int64)
# JobSat
# 6.935041     36311
# 8.000000      7509
# 7.000000      6379
# 6.000000      3751
# 9.000000      3626
# 10.000000     2251
# 5.000000      1956
# 3.000000      1165
# 4.000000      1130
# 2.000000       772
# 0.000000       311
# 1.000000       276
# Name: count, dtype: int64
# YearsCodePro
# 2.0     17995
# 3.0      4093
# 5.0      3526
# 10.0     3251
# 4.0      3215
# 6.0      2843
# 1.0      2639
# 8.0      2549
# 7.0      2517
# 12.0     1777
# 15.0     1635
# 20.0     1549
# 9.0      1493
# 11.0     1312
# 13.0     1127
# 14.0     1082
# 25.0      998
# 16.0      946
# 18.0      867
# 17.0      814
# 30.0      689
# 24.0      632
# 19.0      516
# 22.0      492
# 23.0      448
# 26.0      426
# 21.0      380
# 27.0      380
# 28.0      342
# 35.0      285
# 29.0      196
# 32.0      194
# 40.0      194
# 34.0      169
# 38.0      134
# 33.0      132
# 36.0      119
# 31.0      106
# 37.0      104
# 45.0       56
# 42.0       55
# ...

# %% [markdown]
# ### Step 5: Visualize Job Satisfaction (Focus on JobSat)

# %% [markdown]
# - Create a pie chart or KDE plot to visualize the distribution of `JobSat`.
#
# - Provide an interpretation of the plot, highlighting key trends in job satisfaction.

# %%
print (df['JobSat'].value_counts())
# Out:
# JobSat
# 6.935041     36311
# 8.000000      7509
# 7.000000      6379
# 6.000000      3751
# 9.000000      3626
# 10.000000     2251
# 5.000000      1956
# 3.000000      1165
# 4.000000      1130
# 2.000000       772
# 0.000000       311
# 1.000000       276
# Name: count, dtype: int64

# %%
# To get the values you are looking for the 'count' i.e. the number of answers in the variable.
# Example: visualize JobSat distribution

counts = df['JobSat'].value_counts()
#then draw your pie chart

plt.figure(figsize=(6,6))
plt.pie(counts, autopct='%1.1f%%',labels=counts.index, startangle=90, textprops={'fontsize':4})
plt.title('Distribution by JobSat')
plt.show()

# %% [markdown]
# ### Step 6: Programming Languages Analysis

# %% [markdown]
# - Compare the frequency of programming languages in `LanguageHaveWorkedWith` and `LanguageWantToWorkWith`.
#
# - Visualize the overlap or differences using a Venn diagram or a grouped bar chart.

# %%
# languageHaveWorkedWith and LanguageWantToWorkWith
# Convert to numeric in case of string values
df['LanguageHaveWorkedWith'] = pd.to_numeric(df['LanguageHaveWorkedWith'], errors='coerce')
df['LanguageWantToWorkWith'] = pd.to_numeric(df['LanguageWantToWorkWith'], errors='coerce')

#groupby
avg_Lang = df.groupby('LanguageHaveWorkedWith')['LanguageWantToWorkWith'].mean().sort_values(ascending=False)

#draw the chart
plt.figure(figsize=(10,6))
plt.bar(avg_Lang.index, avg_Lang.values)
plt.xticks(rotation=90)
plt.title('Language Have Worked With by Language Want to Work With')
plt.ylabel('Average Language Worked With')
plt.show()

# %% [markdown]
# ### Step 7: Analyze Remote Work Trends

# %% [markdown]
# - Visualize the distribution of RemoteWork by region using a grouped bar chart or heatmap.

# %%
#Remote work by Region 
#crosstabulate the two varaibles
cross1 = pd.crosstab(df['RemoteWork'], df['Country'])

#draw the heatmap
plt.figure(figsize=(8,6))
sns.heatmap(cross1, annot=True, fmt='d', cmap='Blues')
plt.title('Cross Tabulation: RemoteWork vs Region')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print(df.columns.tolist())
# Out:
# ['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check', 'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline', 'TechDoc', 'YearsCode', 'YearsCodePro', 'DevType', 'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'BuildvsBuy', 'TechEndorse', 'Country', 'Currency', 'CompTotal', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith', 'LanguageAdmired', 'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith', 'DatabaseAdmired', 'PlatformHaveWorkedWith', 'PlatformWantToWorkWith', 'PlatformAdmired', 'WebframeHaveWorkedWith', 'WebframeWantToWorkWith', 'WebframeAdmired', 'EmbeddedHaveWorkedWith', 'EmbeddedWantToWorkWith', 'EmbeddedAdmired', 'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith', 'MiscTechAdmired', 'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith', 'ToolsTechAdmired', 'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'NEWCollabToolsAdmired', 'OpSysPersonal use', 'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith
# ...

# %% [markdown]
# ### Step 8: Correlation between Job Satisfaction and Experience

# %% [markdown]
# - Analyze the correlation between overall job satisfaction (`JobSat`) and `YearsCodePro`.
#
# - Calculate the Pearson or Spearman correlation coefficient.

# %%
 #Step 8: Correlation Between Experience and Job Satisfaction ---

# Convert to numeric in case of string values
df['YearsCodePro'] = pd.to_numeric(df['YearsCodePro'], errors='coerce')
df['JobSatPoints_1'] = pd.to_numeric(df['JobSatPoints_1'], errors='coerce')

corr, p_value = stats.pearsonr(df['YearsCodePro'].dropna(), df['JobSatPoints_1'].dropna())
print(f"Pearson Correlation between Age and Salary: {corr:.2f}, p-value: {p_value:.4f}")

# Correlation heatmap (optional)
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/conda/lib/python3.12/site-packages/scipy/stats/_stats_py.py:4671, in pearsonr(x, y, alternative, method, axis)
#    4670 try:
# -> 4671     np.broadcast_shapes(x.shape, y.shape)
#    4672     # For consistency with other `stats` functions, we need to
#    4673     # match the dimensionalities before looking at `axis`.
#    4674     # (Note: this is not the NEP 5 / gufunc order of operations;
#    4675     #  see TestPearsonr::test_different_dimensionality for more information.)
#
# File /opt/conda/lib/python3.12/site-packages/numpy/lib/_stride_tricks_impl.py:474, in broadcast_shapes(*args)
#     473 arrays = [np.empty(x, dtype=_size0_dtype) for x in args]
# --> 474 return _broadcast_shape(*arrays)
#
# File /opt/conda/lib/python3.12/site-packages/numpy/lib/_stride_tricks_impl.py:419, in _broadcast_shape(*args)
# ...

# %% [markdown]
# ### Step 9: Cross-tabulation Analysis (Employment vs. Education Level)

# %% [markdown]
# - Analyze the relationship between employment status (`Employment`) and education level (`EdLevel`).
#
# - **Instruction**: Create a cross-tabulation using `pd.crosstab()` and visualize it with a stacked bar plot if possible.

# %%
# Example 1: Employment vs Education Level
cross1 = pd.crosstab(df['Employment'], df['EdLevel'])
print(cross1)

# Heatmap
plt.figure(figsize=(8,6))
sns.heatmap(cross1, annot=True, fmt='d', cmap='Blues')
plt.title('Cross Tabulation: Employment vs Education Level')
plt.show()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 7
#       5 # Heatmap
#       6 plt.figure(figsize=(8,6))
# ----> 7 sns.heatmap(cross1, annot=True, fmt='d', cmap='Blues')
#       8 plt.title('Cross Tabulation: Employment vs Education Level')
#       9 plt.show()
#
# File /opt/conda/lib/python3.12/site-packages/seaborn/matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
# ...

# %% [markdown]
# ### Step 10: Export Cleaned Data

# %% [markdown]
# - Save the cleaned dataset to a new CSV file for further use or sharing.

# %%
## Write your code here

# %% [markdown]
# ### Summary:

# %% [markdown]
# In this lab, you practiced key skills in exploratory data analysis, including:

# %% [markdown]
# - Examining the structure and content of the Stack Overflow survey dataset to understand its variables and data types.
#
# - Identifying and addressing missing data to ensure the dataset's quality and completeness.
#
# - Summarizing and visualizing key variables such as job satisfaction, programming languages, and remote work trends.
#
# - Analyzing relationships in the data using techniques like:
#     - Comparing programming languages respondents have worked with versus those they want to work with.
#
#     - Exploring remote work preferences by region.
#
# - Investigating correlations between professional coding experience and job satisfaction.
#
# - Performing cross-tabulations to analyze relationships between employment status and education levels.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# Rav Ahuja
# Lakshmi Holla
# Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
